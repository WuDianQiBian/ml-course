# %% [markdown]
# # Video Embed In Text Block (Base64 + Poster)
#
# 下面视频使用 Base64 内嵌，封面是视频最后一帧（同样 Base64 内嵌）。
#
# <video controls preload="metadata" width="960" style="max-width:100%; border:1px solid #ddd; border-radius:10px; background:#000;" poster="data:image/jpeg;base64,..." src="data:video/mp4;base64,..."></video>
