# %% [markdown]
# # Video Embed In Text Block
#
# <video controls width="960" style="max-width:100%; border:1px solid #ddd; border-radius:10px; background:#000;" preload="metadata" src="/files/notebooks/remotion_demo.mp4"></video>
#
# 如果你不是在仓库根目录启动 Jupyter，请确认 `notebooks/remotion_demo.mp4` 这个路径存在。
