# %% [markdown]
# # Video Embed In Text Block (Base64 + Poster)
#
# <video controls preload="metadata" width="960" style="max-width:100%; border:1px solid #ddd; border-radius:10px; background:#000;" poster="data:image/jpeg;base64,..." src="data:video/mp4;base64,...">Video preview: Remotion-style animation with black background and cyan moving square.</video>
